# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?
df = pd.read_excel('flight_price.xlsx')
df.shape
'''Number of rows - 10683 and number of columns - 11)'''
# Out:
# 'Number of rows - 10683 and number of columns - 11)'

# %%
#Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
sns.histplot(df,kde = True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
#Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
minimum,maximum = np.quantile(df['Price'],[0,1.0])
print('minimum price: ',minimum,'maximum price: ',maximum)
# Out:
# minimum price:  1759.0 maximum price:  79512.0

# %%
#Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.
sns.boxplot(x='Airline', y='Price', data=df)
# Out:
# <AxesSubplot: xlabel='Airline', ylabel='Price'>

# %%
#Q5.Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.
'''Yes , There are many outliers.

Investigate the outliers: Examine the potential outliers and verify if they are legitimate data points or errors. Outliers can result from 
measurement errors, data entry mistakes, or genuine extreme values. It's important to determine the source of the outliers to decide how to
handle them appropriately.
Understand the context: Consider the nature of your data and the specific analysis you're conducting. Determine if the outliers are valid
data points that represent genuine extreme values or if they are data errors that should be corrected.
Decide on the appropriate action: Depending on the situation, you have several options for dealing with outliers. You can:
Remove the outliers: If the outliers are determined to be data errors or they significantly impact the analysis, you may choose to remove 
them from the dataset. However, exercise caution when removing outliers, as it should be done judiciously and based on sound reasoning.
Transform the data: In some cases, transforming the data using mathematical operations (such as logarithmic or square root transformations)
can mitigate the impact of outliers and make the distribution more suitable for analysis.
Report separately: If the outliers are valid data points and removing them would not be appropriate, you can report them separately in your
analysis, acknowledging their presence and potential impact on the results.
Sensitivity analysis: Perform sensitivity analyses by running the analysis with and without the outliers to assess their influence on the 
results. This can help determine the robustness of your findings and the degree to which the outliers affect your conclusions.
'''
# Out:
# "Yes , There are many outliers.\n\nInvestigate the outliers: Examine the potential outliers and verify if they are legitimate data points or errors. Outliers can result from \nmeasurement errors, data entry mistakes, or genuine extreme values. It's important to determine the source of the outliers to decide how to\nhandle them appropriately.\nUnderstand the context: Consider the nature of your data and the specific analysis you're conducting. Determine if the outliers are valid\ndata points that represent genuine extreme values or if they are data errors that should be corrected.\nDecide on the appropriate action: Depending on the situation, you have several options for dealing with outliers. You can:\nRemove the outliers: If the outliers are determined to be data errors or they significantly impact the analysis, you may choose to remove \nthem from the dataset. However, exercise caution when removing outliers, as it should be done judiciously and based on sound reasoning.\nTransform
# ...

# %%
'''Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
to identify the peak travel season. What features would you analyze to identify the peak season, and how
would you present your findings to your boss?'''



'''I will choose 'Date_of_Journey' features to identify the peak season, I will convert the 'Date_of_Journey' to date_time from object
type then find out the maximum occuring month then we can identify the  peak travel season'''
df['month'] = pd.to_datetime(df['Date_of_Journey']).dt.month
df['month'].value_counts()
'''We can clearly observe that 6th month means in summer time people travel highest '''
# Out:
# /tmp/ipykernel_1268/1915488984.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['month'] = pd.to_datetime(df['Date_of_Journey']).dt.month
# 'We can clearly observe that 6th month means in summer time people travel highest '

# %%
'''Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
Price dataset to identify any trends in flight prices. What features would you analyze to identify these
trends, and what visualizations would you use to present your findings to your team?'''


''' I will choose 'Price' feature to identify any trends in flight prices, I would use histplot  to present my findings to my team'''
# Out:
# " I will choose 'Price' feature to identify any trends in flight prices, I would use histplot  to present my findings to my team"

# %%
"""Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
identify these factors, and how would you present your findings to the management team?
"""
""" I will choose 'Date_of_Journey','Source', 'Destination', 'Dep_Time', 'Arrival_Time', and 'Duration'features to identify the factors
that effects the price because it may happen that in a particular season the price is high, or from differenct different source and 
different destination cause change in price, also dept_time and arrival time palys a vital role. It may happen prices varies
according to day or time time arrival and dept time or the hours of journey can effect flight price also

I will present each of the above feature with price feature using distribution plot and relational plot.
"""
# Out:
# " I will choose 'Date_of_Journey','Source', 'Destination', 'Dep_Time', 'Arrival_Time', and 'Duration'features to identify the factors\nthat effects the price because it may happen that in a particular season the price is high, or from differenct different source and \ndifferent destination cause change in price, also dept_time and arrival time palys a vital role. It may happen prices varies\naccording to day or time time arrival and dept time or the hours of journey can effect flight price also\n\nI will present each of the above feature with price feature using distribution plot and relational plot.\n"

# %%
#Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?
df2 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df2.shape
'''Number of rows - 10841 and number of columns - 13)'''
# Out:
# 'Number of rows - 10841 and number of columns - 13)'

# %%
#Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.
sns.boxplot(x= 'Category',y='Rating',data=df2)
# Out:
# <AxesSubplot: xlabel='Category', ylabel='Rating'>

# %%
#Q11.Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.
df2.isnull().sum()
''' Yes missing values are present in the dataset,the 'Rating ' feature have the most missing values it will decrese the accuracy of the
model'''
# Out:
# " Yes missing values are present in the dataset,the 'Rating ' feature have the most missing values it will decrese the accuracy of the\nmodel"

# %%
#Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.
sns.scatterplot(x=df2.Size,y= df2.Rating)
''' Apps with less size have the ratingsbetween 1 to 5, as the size of the app increses rating is mostly 5 .'''
# Out:
# ' Apps with less size have the ratingsbetween 1 to 5, as the size of the app increses rating is mostly 5 .'

# %%
#Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.
df_copy = df2.copy()

df_copy['Price'] = df_copy['Price'].str.replace('$','')
df_copy['Price'] = df_copy['Price'].str.replace('Everyone','0')

df_copy['Price'] = df_copy['Price'].astype('float')
sns.barplot(x = 'Type',
            y = 'Price',
            data = df_copy)
plt.show()
# Out:
# /tmp/ipykernel_1268/3713655022.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy['Price'] = df_copy['Price'].str.replace('$','')

# %%
'''Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest 
number of installs.'''
category = pd.DataFrame(df2['Category'].value_counts())        
category.rename(columns = {'Category':'Count'},inplace=True)
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
'''Q15.A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the
most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the 
company?'''




''' I will findout the top 10 most used popular app from the dataset to make recommendations to the company'''
# Out:
# ' I will findout the top 10 most used popular app from the dataset to make recommendations to the company'

# %%
'''
Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What
features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?'''


''' I will suggest app categories with highest rating as  the most successful app developers, I will use barplot to analyze the app with
highest rating'''

sns.barplot(x=df2.Category,y= df2.Rating)
plt.show()

# %%
'''Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What
features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?'''


''' There is no features that can identify the best time to launch '''
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
