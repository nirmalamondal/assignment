# %%
"""Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine."""

import pandas as pd
df = pd.read_csv('winequality-red.csv')
col = df.columns
print("the key features of the wine quality data set are: ",col)
import matplotlib.pyplot as plt
import  seaborn as sns
plt.figure(figsize = (10,6))
sns.heatmap(df.corr(),annot = True)
"""  
1.'fixed acidity'  - is not so important to prdicting the quality of wine as we see coefficient between them is not so high.
2.'volatile acidity' - is negativly corelated with quality of wine means if 'volatile acidity' is incresed then quality of wine will decresed.
3.'citric acid' - is modarate positive corelated with quality of wine .
4.residual sugar - is slightly positive corelated with quality of wine , it is not so much effective feature. 
5.chlorides - is negativly corelated with quality of wine means if 'chlorides' is incresed then quality of wine will decresed.
6.free sulfur dioxide -is little bit negativly corelated with quality of wine , it is not so much effective ffeature. 
7.total sulfur dioxide - is negativly corelated with quality of wine means if 'density' is incresed then quality of wine will decresed.
8.density - is negativly corelated with quality of wine means if 'density' is incresed then quality of wine will decresed.
9.pH - is little bit negativly corelated with quality of wine , it is not so much effective ffeature.
10.sulphates - this feature is highly positivle corelated with each other means if amount of alcohol increased then quallity of wine also increased.
11.alcohol - this feature is highly positivle corelated with each other means if amount of alcohol increased then quallity of wine also increased.
"""
# Out:
# the key features of the wine quality data set are:  Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# "  \n1.'fixed acidity'  - is not so important to prdicting the quality of wine as we see coefficient between them is not so high.\n2.'volatile acidity' - is negativly corelated with quality of wine means if 'volatile acidity' is incresed then quality of wine will decresed.\n3.'citric acid' - is modarate positive corelated with quality of wine .\n4.residual sugar - is slightly positive corelated with quality of wine , it is not so much effective feature. \n5.chlorides - is negativly corelated with quality of wine means if 'chlorides' is incresed then quality of wine will decresed.\n6.free sulfur dioxide -is little bit negativly corelated with quality of wine , it is not so much effective ffeature. \n7.total sulfur dioxide - is negativly corelated with quality of wine means if 'density' is incresed then quality of wine will decresed.\n8.density - is negativly corelated with quality of wine means if 'density' is incresed then quality of wine will decresed.\n9.pH - is little bit negativly corelated with quality of wine , it is not so much effective ffeature.\n10.sulphates - this feature is highly positivle corelated with each other means if amount of alcohol increased then quallity of wine also increased.\n11.alcohol - this feature is highly positivle corelated with each other means if amount of alcohol increased then quallity of wine also increased.\n"

# %%
"""Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
Discuss the advantages and disadvantages of different imputation techniques."""

df.info()

""" As all the features are have numreric values then we can handel missing values using mean of that feature if outliers are not present or we can use
median to handel missing values if outliers are  present. """
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# ' As all the features are have numreric values then we can handel missing values using mean of that feature if outliers are not present or we can use\nmedian to handel missing values if outliers are  present. '

# %%
"""Q3.What are the key factors that affect students' performance in exams? How would you go about
analyzing these factors using statistical techniques?"""

df2 = pd.read_csv('StudentsPerformance.csv')
print("the key features of the wine quality data set are: ",df2.columns)

"""I will calculate mean,mode,median,standard deviation, variance,correlation, covariance and analyzing these factors"""
print("Mean: " , dict(df2.mean()))
print("Median: " , dict(df2.median()))
print("standard deviation: " , dict(df2.std()))
print("covariance: " , df2.cov())
print("corelation: " , df2.corr())
# Out:
# the key features of the wine quality data set are:  Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')
# Mean:  {'math score': 66.089, 'reading score': 69.169, 'writing score': 68.054}
# Median:  {'math score': 66.0, 'reading score': 70.0, 'writing score': 69.0}
# standard deviation:  {'math score': 15.163080096009468, 'reading score': 14.60019193725222, 'writing score': 15.195657010869642}
# covariance:                 math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992
# corelation:                 math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000
# /tmp/ipykernel_84/3961331016.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Mean: " , dict(df2.mean()))
# /tmp/ipykernel_84/3961331016.py:9: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Median: " , dict(df2.median()))
# /tmp/ipykernel_84/3961331016.py:10: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("standard deviation: " , dict(df2.std()))
# /tmp/ipykernel_84/3961331016.py:11: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("covariance: " , df2.cov())
# /tmp/ipykernel_84/3961331016.py:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("corelation: " , df2.corr())

# %%
"""Q4. Describe the process of feature engineering in the context of the student performance data set. How
did you select and transform the variables for your model?"""
# check the information of whole dataset
print(df2.info())
#Then check that is there any null values or not
print(df2.isnull().sum())
#here no null values is present so then no need to handel missing values
# Then find out the numric features and catagorical features of that dataset
n_fea = [feature for feature in df.columns if df[feature].dtype != 'O']
c_fea = [feature for feature in df.columns if df[feature].dtype == 'O']
# then calculate the avarage marks and total marls of each student and add new columns to the dataset of those values
df2['avg_score'] = df2[['math score', 'reading score', 'writing score']].mean(axis = 1)
df2['total_score'] = df2[['math score', 'reading score', 'writing score']].sum(axis = 1)
print(df2)
# findout correlation with each other
print("Correlation : ",df2.corr())
#Visualize the data set in different different way
fig,axis = plt.subplots(1,2,figsize=(20,10))
plt.subplot(121)
sns.histplot(data = df2, x='avg_score',bins = 30,kde = True,color= 'seagreen')


fig,axis = plt.subplots(1,3,figsize=(25,8))
plt.subplot(141)
sns.histplot(data = df2, x='avg_score',kde = True,hue = 'lunch')
plt.subplot(142)
sns.histplot(data = df2[df2.gender == 'female'], x='avg_score',kde = True,hue = 'lunch')
plt.subplot(143)
sns.histplot(data = df2[df2.gender == 'male'], x='avg_score',kde = True,hue = 'lunch')


fig,axis = plt.subplots(1,3,figsize=(25,8))
plt.subplot(141)
sns.histplot(data = df2, x='avg_score',kde = True,hue = 'race/ethnicity')
plt.subplot(142)
sns.histplot(data = df2[df2.gender == 'female'], x='avg_score',kde = True,hue = 'race/ethnicity')
plt.subplot(143)
sns.histplot(data = df2[df2.gender == 'male'], x='avg_score',kde = True,hue = 'race/ethnicity')

sns.heatmap(df2.corr(),annot = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   avg_score                    1000 non-null   float64
#  9   total_score                  1000 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.2+ KB
# None
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# avg_score                      0
# total_score                    0
# dtype: int64
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      avg_score  total_score
# 0    72.666667          218
# 1    82.333333          247
# 2    92.666667          278
# 3    49.333333          148
# 4    76.333333          229
# ..         ...          ...
# 995  94.000000          282
# 996  57.333333          172
# 997  65.000000          195
# 998  74.333333          223
# 999  83.000000          249
#
# [1000 rows x 10 columns]
# Correlation :                 math score  reading score  writing score  avg_score  \
# math score       1.000000       0.817580       0.802642   0.918746
# reading score    0.817580       1.000000       0.954598   0.970331
# writing score    0.802642       0.954598       1.000000   0.965667
# avg_score        0.918746       0.970331       0.965667   1.000000
# total_score      0.918746       0.970331       0.965667   1.000000
#
#                total_score
# math score        0.918746
# reading score     0.970331
# writing score     0.965667
# avg_score         1.000000
# total_score       1.000000
# /tmp/ipykernel_84/3387838604.py:16: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Correlation : ",df2.corr())
# /tmp/ipykernel_84/3387838604.py:24: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/3387838604.py:26: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/3387838604.py:28: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# /tmp/ipykernel_84/3387838604.py:33: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/3387838604.py:35: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/3387838604.py:37: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# /tmp/ipykernel_84/3387838604.py:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(),annot = True)
# <AxesSubplot: >

# %%
"""Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
these features to improve normality?"""
#Import all the libaries.
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns

#lOAD DATASET
df3 = pd.read_csv('winequality-red.csv')

#See shape of data
print("shape : ",df3.shape)
""" 1592 rows and 12 columns are present in dataset"""
#VIEW SOME INITIAL DATAPOINTS
print(df3.head())

#NOW WE ARE GOING TO CHECK FOR MISSING VALUES
print(df3.isnull().sum())

""" There we can see no missing values are present in dataset ."""
#now see the over all information
print("Overall INformation of the dataset : ",df3.info())

"""From informaton we can observe that there are only float and integer values are present so need of encoding. """
#Now calculate the unique value of each feature.
for i in df3.columns.values:
    print("Unique value of  ",format(i),"is :" ,df3[i].nunique())
"""From the above code we can conclude that 'Density' have maximum number of unique values and 'quality' have minimum number of unique feature."""
#Now describe the all features
print(df3.describe())

"""We can conclude that from min to max percentile the difference is high of 'free sulfur dioxide' and  'total sulfur dioxide' feature."""
# check for duplicate data
print(df3[df3.duplicated()])
"""Here we can see duplicate datas  are present so remove all duplicate datas"""
df3.drop_duplicates(inplace = True)

# Generate correlation
print(df3.corr())
"""alcohol feature is highly positivly corelated with quality means if amount of alcohol increased then quallity of wine also increased."""
#Generate heatmap
plt.subplots(1,3,figsize=(25,8))
plt.subplot(141)
sns.heatmap(df3.corr(),annot = True)
"""1.density has a strong positive correlation with residual sugar, whereas it has a strong negative correlation with alcohol.
2.pH & fixed acidity has negative correlation.
3.density & fixed acidity has positive correlation.
4.citric acid & fixed acidity has positive correlation.
5.citric acid & volatile acidity has negative correlation.
6.free sulphur dioxide & total sulphur dioxide has positive correlation."""
# draw the count plot to visualise the number data for each quality of wine.
plt.subplot(142)
df3['quality'].value_counts().plot(kind = 'bar')
''' quality of 5 wine have maximum number and  quality of 3 have minimum number   '''
#scatterplot 
plt.subplot(143)
sns.scatterplot(x= 'alcohol',y ='pH',hue = 'quality',data = df)
'''we can see that wine with pH 4 have the quality of 5 to 6 in range'''
# Out:
# shape :  (1599, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# Overall INformation of the dataset :  None
# Unique value of   fixed acidity is : 96
# Unique value of   volatile acidity is : 143
# Unique value of   citric acid is : 80
# Unique value of   residual sugar is : 91
# Unique value of   chlorides is : 153
# Unique value of   free sulfur dioxide is : 60
# Unique value of   total sulfur dioxide is : 144
# Unique value of   density is : 436
# Unique value of   pH is : 89
# Unique value of   sulphates is : 96
# Unique value of   alcohol is : 65
# Unique value of   quality is : 6
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality
# 4         9.4        5
# 11       10.5        5
# 27        9.5        5
# 40       10.5        5
# 65       10.9        5
# ...       ...      ...
# 1563     10.1        5
# 1564     10.1        5
# 1567     10.1        5
# 1581     11.3        5
# 1596     11.0        6
#
# [240 rows x 12 columns]
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.111025   0.085886            -0.140580
# volatile acidity           -0.002449   0.055154            -0.020945
# citric acid                 0.143892   0.210195            -0.048004
# residual sugar              1.000000   0.026656             0.160527
# chlorides                   0.026656   1.000000             0.000749
# free sulfur dioxide         0.160527   0.000749             1.000000
# total sulfur dioxide        0.201038   0.045773             0.667246
# density                     0.324522   0.193592            -0.018071
# pH                         -0.083143  -0.270893             0.056631
# sulphates                  -0.011837   0.394557             0.054126
# alcohol                     0.063281  -0.223824            -0.080125
# quality                     0.013640  -0.130988            -0.050463
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.103777  0.670195 -0.686685   0.190269
# volatile acidity                  0.071701  0.023943  0.247111  -0.256948
# citric acid                       0.047358  0.357962 -0.550310   0.326062
# residual sugar                    0.201038  0.324522 -0.083143  -0.011837
# chlorides                         0.045773  0.193592 -0.270893   0.394557
# free sulfur dioxide               0.667246 -0.018071  0.056631   0.054126
# total sulfur dioxide              1.000000  0.078141 -0.079257   0.035291
# density                           0.078141  1.000000 -0.355617   0.146036
# pH                               -0.079257 -0.355617  1.000000  -0.214134
# sulphates                         0.035291  0.146036 -0.214134   1.000000
# alcohol                          -0.217829 -0.504995  0.213418   0.091621
# quality                          -0.177855 -0.184252 -0.055245   0.248835
#
#                        alcohol   quality
# fixed acidity        -0.061596  0.119024
# volatile acidity     -0.197812 -0.395214
# citric acid           0.105108  0.228057
# residual sugar        0.063281  0.013640
# chlorides            -0.223824 -0.130988
# free sulfur dioxide  -0.080125 -0.050463
# total sulfur dioxide -0.217829 -0.177855
# density              -0.504995 -0.184252
# pH                    0.213418 -0.055245
# sulphates             0.091621  0.248835
# alcohol               1.000000  0.480343
# quality               0.480343  1.000000
# /tmp/ipykernel_84/298364116.py:44: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/298364116.py:53: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/298364116.py:57: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# 'we can see that wine with pH 4 have the quality of 5 to 6 in range'

# %%
"""Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
features. What is the minimum number of principal components required to explain 90% of the variance in
the data?"""
#Import necessary libraries
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split


#lOAD DATASET
df3 = pd.read_csv('winequality-red.csv')


#See shape of data
print("shape : ",df3.shape)
""" 1592 rows and 12 columns are present in dataset"""


#VIEW SOME INITIAL DATAPOINTS
print(df3.head())

#NOW WE ARE GOING TO CHECK FOR MISSING VALUES
print(df3.isnull().sum())
""" There we can see no missing values are present in dataset ."""


#now see the over all information
print("Overall INformation of the dataset : ",df3.info())
"""From informaton we can observe that there are only float and integer values are present so need of encoding. """


#Now calculate the unique value of each feature.
for i in df3.columns.values:
    print("Unique value of  ",format(i),"is :" ,df3[i].nunique())
"""From the above code we can conclude that 'Density' have maximum number of unique values and 'quality' have minimum number of unique feature."""


#Now describe the all features
print(df3.describe())
"""We can conclude that from min to max percentile the difference is high of 'free sulfur dioxide' and  'total sulfur dioxide' feature."""


# check for duplicate data
print(df3[df3.duplicated()])
"""Here we can see duplicate datas  are present so remove all duplicate datas"""
df3.drop_duplicates(inplace = True)

#Checking Co-relation between features before PCA
plt.plot(1,3,figsize=(25,8))
plt.subplot(141)
sns.heatmap(df3.corr(),annot = True)
"""1.density has a strong positive correlation with residual sugar, whereas it has a strong negative correlation with alcohol.
2.pH & fixed acidity has negative correlation.
3.density & fixed acidity has positive correlation.
4.citric acid & fixed acidity has positive correlation.
5.citric acid & volatile acidity has negative correlation.
6.free sulphur dioxide & total sulphur dioxide has positive correlation."""

#Standardize the features
scalar = StandardScaler()
scaled_data = pd.DataFrame(scalar.fit_transform(df3)) 
print(scaled_data)

#Applying Principal Component Analysis
pca = PCA(n_components = 12)
data_pca = pca.fit_transform(scaled_data)
data_pca = pd.DataFrame(data_pca,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12'])
data_pca.head()

#Checking Co-relation between features after PCA
plt.subplot(142)
sns.heatmap(data_pca.corr())
# Out:
# shape :  (1599, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# Overall INformation of the dataset :  None
# Unique value of   fixed acidity is : 96
# Unique value of   volatile acidity is : 143
# Unique value of   citric acid is : 80
# Unique value of   residual sugar is : 91
# Unique value of   chlorides is : 153
# Unique value of   free sulfur dioxide is : 60
# Unique value of   total sulfur dioxide is : 144
# Unique value of   density is : 436
# Unique value of   pH is : 89
# Unique value of   sulphates is : 96
# Unique value of   alcohol is : 65
# Unique value of   quality is : 6
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality
# 4         9.4        5
# 11       10.5        5
# 27        9.5        5
# 40       10.5        5
# 65       10.9        5
# ...       ...      ...
# 1563     10.1        5
# 1564     10.1        5
# 1567     10.1        5
# 1581     11.3        5
# 1596     11.0        6
#
# [240 rows x 12 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 53
#      50 df3.drop_duplicates(inplace = True)
#      52 #Checking Co-relation between features before PCA
# ---> 53 plt.plot(1,3,figsize=(25,8))
#      54 plt.subplot(141)
#      55 sns.heatmap(df3.corr(),annot = True)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:544, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:544, in <listcomp>(.0)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:537, in <genexpr>(.0)
#     534 else:
#     535     labels = [label] * n_datasets
# --> 537 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     538                       {**kwargs, 'label': label})
#     539           for j, label in enumerate(labels))
#     541 if return_kwargs:
#     542     return list(result)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/lines.py:393, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     389 self.set_markeredgewidth(markeredgewidth)
#     391 # update kwargs before updating data to give the caller a
#     392 # chance to init axes (and hence unit support)
# --> 393 self._internal_update(kwargs)
#     394 self._pickradius = pickradius
#     395 self.ind_offset = 0
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/artist.py:1186, in Artist._internal_update(self, kwargs)
#    1179 def _internal_update(self, kwargs):
#    1180     """
#    1181     Update artist properties without prenormalizing them, but generating
#    1182     errors as if calling `set`.
#    1183
#    1184     The lack of prenormalization is to maintain backcompatibility.
#    1185     """
# -> 1186     return self._update_props(
#    1187         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1188         "{prop_name!r}")
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/artist.py:1160, in Artist._update_props(self, props, errfmt)
#    1158             func = getattr(self, f"set_{k}", None)
#    1159             if not callable(func):
# -> 1160                 raise AttributeError(
#    1161                     errfmt.format(cls=type(self), prop_name=k))
#    1162             ret.append(func(v))
#    1163 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'figsize'
